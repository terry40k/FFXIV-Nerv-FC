# %%
import requests
from bs4 import BeautifulSoup
import random
from IPython.display import display, Image, HTML
from collections import defaultdict

# Updated list of Nerv FC members in the drawing
fc_members = [
    "Shiwo Chrysalis", "Hale Draco", "Albatoss Balong", "Jovian Balong", "Elysia Kharim", 
    "Luceth Marithine", "Suija Qualli", "Mozeo Oakden", "Maki Moonfire", "Apple Angelbow", 
    "Deuce Halifax", "Mia Orange", "Rurvyn Reledran", "Sien Clark", "Lina Lapis"
]

# Function to fetch character profile image and details from FFXIV Lodestone
def get_character_info(name):
    search_url = f"https://na.finalfantasyxiv.com/lodestone/character/?q={name.replace(' ', '+')}&worldname=Lamia"
    response = requests.get(search_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Attempt to find the character profile link
    character_link = soup.find('a', class_='entry__link')
    if not character_link:
        print(f"Could not find character profile for {name} on Lamia")
        return None, None

    character_url = f"https://na.finalfantasyxiv.com{character_link['href']}"
    response = requests.get(character_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Attempt to find the profile image
    image_tag = soup.find('div', class_='character__detail__image')
    if not image_tag:
        print(f"Could not find profile image for {name}")
        return None, None

    image_url = image_tag.find('img')['src']

    # Attempt to find additional character details
    details_tag = soup.find('div', class_='character__profile__data')
    if details_tag:
        details = details_tag.get_text(strip=True, separator='\n').split('\n')
    else:
        details = ["Details not found."]

    return image_url, details

# Function to create HTML table for character details
def create_details_table(details):
    table_html = "<h2>Winning FC Member Details</h2><table><tr><th>Details</th></tr>"
    for detail in details:
        table_html += f"<tr><td>{detail}</td></tr>"
        if "Attributes" in detail:
            break
    table_html += "</table>"
    return table_html

# Function to create HTML table for closest members
def create_closest_table(closest_counts):
    table_html = "<h2>Closest FC Members to Winning Number</h2><table><tr><th>Member</th><th>Total Count</th></tr>"
    for member, count in closest_counts.items():
        table_html += f"<tr><td>{member}</td><td>{count}</td></tr>"
    table_html += "</table>"
    return table_html

# Function to display statistics
def display_statistics(simulation_count, winners):
    stats_html = "<h2>Simulation Statistics</h2><table><tr><th>Statistic</th><th>Value</th></tr>"
    stats_html += f"<tr><td>Total Simulations</td><td>{simulation_count}</td></tr>"
    stats_html += f"<tr><td>Total Winners</td><td>{len(winners)}</td></tr>"
    stats_html += "</table>"
    display(HTML(stats_html))

# Function to run the simulations
def run_simulations():
    winning_number = int(input("Enter the winning number (between 1 and 999): "))
    
    # Validate the input number
    if winning_number < 1 or winning_number > 999:
        print("The number must be between 1 and 999.")
        return
    
    simulation_count = 0
    winners = []
    closest_counts = defaultdict(int)

    for i in range(100):
        simulation_count += 1
        print(f"\nSimulation {i+1}")
        closest_diff = float('inf')
        closest_member = None

        for fc_member in fc_members:
            rolled_number = random.randint(1, 999)
            print(f"{fc_member} rolled: {rolled_number}")
            diff = abs(rolled_number - winning_number)
            if diff <= 10:
                closest_counts[fc_member] += 1

            if rolled_number == winning_number:
                image_url, details = get_character_info(fc_member)
                if image_url:
                    print(f"\n{fc_member} wins the Dawntrail raffle with the number {winning_number}!\n")
                    display(Image(url=image_url))
                    details_table = create_details_table(details)
                    display(HTML(details_table))
                    winners.append(fc_member)
                    display_statistics(simulation_count, winners)
                    closest_table = create_closest_table(closest_counts)
                    display(HTML(closest_table))
                    return

        print("No winner in this simulation.")
    
    # Display final statistics and closest members
    display_statistics(simulation_count, winners)
    closest_table = create_closest_table(closest_counts)
    display(HTML(closest_table))

# Run the simulations
run_simulations()
# Out:
# Enter the winning number (between 1 and 999):  777
# Simulation 1
# Shiwo Chrysalis rolled: 933
# Hale Draco rolled: 620
# Albatoss Balong rolled: 725
# Jovian Balong rolled: 254
# Elysia Kharim rolled: 865
# Luceth Marithine rolled: 28
# Suija Qualli rolled: 411
# Mozeo Oakden rolled: 372
# Maki Moonfire rolled: 529
# Apple Angelbow rolled: 992
# Deuce Halifax rolled: 463
# Mia Orange rolled: 272
# Rurvyn Reledran rolled: 582
# Sien Clark rolled: 413
# Lina Lapis rolled: 899
# No winner in this simulation.
#
# Simulation 2
# Shiwo Chrysalis rolled: 657
# Hale Draco rolled: 858
# Albatoss Balong rolled: 943
# Jovian Balong rolled: 94
# Elysia Kharim rolled: 130
# Luceth Marithine rolled: 631
# Suija Qualli rolled: 10
# Mozeo Oakden rolled: 265
# Maki Moonfire rolled: 937
# Apple Angelbow rolled: 448
# Deuce Halifax rolled: 951
# Mia Orange rolled: 404
# Rurvyn Reledran rolled: 605
# Sien Clark rolled: 964
# Lina Lapis rolled: 910
# No winner in this simulation.
#
# Simulation 3
# Shiwo Chrysalis rolled: 446
# Hale Draco rolled: 58
# Albatoss Balong rolled: 979
# Jovian Balong rolled: 235
# Elysia Kharim rolled: 52
# Luceth Marithine rolled: 625
# Suija Qualli rolled: 383
# Mozeo Oakden rolled: 456
# Maki Moonfire rolled: 35
# Apple Angelbow rolled: 22
# Deuce Halifax rolled: 78
# Mia Orange rolled: 717
# Rurvyn Reledran rolled: 863
# Sien Clark rolled: 192
# Lina Lapis rolled: 83
# No winner in this simulation.
#
# Simulation 4
# Shiwo Chrysalis rolled: 923
# Hale Draco rolled: 221
# Albatoss Balong rolled: 623
# Jovian Balong rolled: 975
# Elysia Kharim rolled: 545
# Luceth Marithine rolled: 405
# Suija Qualli rolled: 922
# Mozeo Oakden rolled: 994
# Maki Moonfire rolled: 938
# Apple Angelbow rolled: 316
# Deuce Halifax rolled: 311
# Mia Orange rolled: 724
# Rurvyn Reledran rolled: 128
# Sien Clark rolled: 373
# Lina Lapis rolled: 708
# No winner in this simulation.
#
# Simulation 5
# Shiwo Chrysalis rolled: 636
# Hale Draco rolled: 317
# Albatoss Balong rolled: 243
# Jovian Balong rolled: 289
# Elysia Kharim rolled: 71
# Luceth Marithine rolled: 949
# Suija Qualli rolled: 37
# Mozeo Oakden rolled: 81
# Maki Moonfire rolled: 40
# Apple Angelbow rolled: 916
# Deuce Halifax rolled: 932
# Mia Orange rolled: 627
# Rurvyn Reledran rolled: 914
# Sien Clark rolled: 104
# Lina Lapis rolled: 829
# No winner in this simulation.
#
# Simulation 6
# Shiwo Chrysalis rolled: 578
# Hale Draco rolled: 859
# Albatoss Balong rolled: 80
# Jovian Balong rolled: 347
# Elysia Kharim rolled: 793
# Luceth Marithine rolled: 307
# Suija Qualli rolled: 334
# Mozeo Oakden rolled: 912
# Maki Moonfire rolled: 505
# Apple Angelbow rolled: 279
# Deuce Halifax rolled: 466
# Mia Orange rolled: 438
# Rurvyn Reledran rolled: 932
# Sien Clark rolled: 665
# Lina Lapis rolled: 217
# No winner in this simulation.
#
# Simulation 7
# Shiwo Chrysalis rolled: 282
# Hale Draco rolled: 85
# Albatoss Balong rolled: 192
# Jovian Balong rolled: 665
# Elysia Kharim rolled: 74
# Luceth Marithine rolled: 250
# Suija Qualli rolled: 650
# Mozeo Oakden rolled: 481
# Maki Moonfire rolled: 629
# Apple Angelbow rolled: 920
# Deuce Halifax rolled: 360
# Mia Orange rolled: 848
# Rurvyn Reledran rolled: 959
# Sien Clark rolled: 875
# Lina Lapis rolled: 154
# No winner in this simulation.
#
# Simulation 8
# Shiwo Chrysalis rolled: 835
# Hale Draco rolled: 522
# Albatoss Balong rolled: 551
# Jovian Balong rolled: 882
# Elysia Kharim rolled: 601
# Luceth Marithine rolled: 443
# Suija Qualli rolled: 422
# Mozeo Oakden rolled: 220
# Maki Moonfire rolled: 88
# Apple Angelbow rolled: 243
# Deuce Halifax rolled: 808
# Mia Orange rolled: 12
# Rurvyn Reledran rolled: 963
# Sien Clark rolled: 838
# Lina Lapis rolled: 35
# No winner in this simulation.
#
# Simulation 9
# Shiwo Chrysalis rolled: 392
# Hale Draco rolled: 841
# Albatoss Balong rolled: 192
# Jovian Balong rolled: 734
# Elysia Kharim rolled: 172
# Luceth Marithine rolled: 406
# Suija Qualli rolled: 838
# Mozeo Oakden rolled: 916
# Maki Moonfire rolled: 231
# Apple Angelbow rolled: 309
# Deuce Halifax rolled: 92
# Mia Orange rolled: 162
# Rurvyn Reledran rolled: 723
# Sien Clark rolled: 400
# Lina Lapis rolled: 376
# No winner in this simulation.
#
# Simulation 10
# Shiwo Chrysalis rolled: 23
# Hale Draco rolled: 64
# Albatoss Balong rolled: 612
# Jovian Balong rolled: 402
# Elysia Kharim rolled: 873
# Luceth Marithine rolled: 421
# Suija Qualli rolled: 944
# Mozeo Oakden rolled: 471
# Maki Moonfire rolled: 397
# Apple Angelbow rolled: 859
# Deuce Halifax rolled: 995
# Mia Orange rolled: 948
# Rurvyn Reledran rolled: 812
# Sien Clark rolled: 105
# Lina Lapis rolled: 124
# No winner in this simulation.
#
# Simulation 11
# Shiwo Chrysalis rolled: 251
# Hale Draco rolled: 304
# Albatoss Balong rolled: 618
# Jovian Balong rolled: 263
# Elysia Kharim rolled: 789
# Luceth Marithine rolled: 673
# Suija Qualli rolled: 109
# Mozeo Oakden rolled: 948
# Maki Moonfire rolled: 769
# Apple Angelbow rolled: 630
# Deuce Halifax rolled: 533
# Mia Orange rolled: 640
# Rurvyn Reledran rolled: 606
# Sien Clark rolled: 981
# Lina Lapis rolled: 371
# No winner in this simulation.
#
# Simulation 12
# Shiwo Chrysalis rolled: 961
# Hale Draco rolled: 489
# Albatoss Balong rolled: 725
# Jovian Balong rolled: 554
# Elysia Kharim rolled: 983
# Luceth Marithine rolled: 690
# Suija Qualli rolled: 786
# Mozeo Oakden rolled: 47
# Maki Moonfire rolled: 65
# Apple Angelbow rolled: 755
# Deuce Halifax rolled: 756
# Mia Orange rolled: 402
# Rurvyn Reledran rolled: 372
# Sien Clark rolled: 457
# Lina Lapis rolled: 229
# No winner in this simulation.
#
# Simulation 13
# Shiwo Chrysalis rolled: 118
# Hale Draco rolled: 251
# Albatoss Balong rolled: 512
# Jovian Balong rolled: 206
# Elysia Kharim rolled: 757
# Luceth Marithine rolled: 918
# Suija Qualli rolled: 652
# Mozeo Oakden rolled: 503
# Maki Moonfire rolled: 19
# Apple Angelbow rolled: 319
# Deuce Halifax rolled: 847
# Mia Orange rolled: 703
# Rurvyn Reledran rolled: 452
# Sien Clark rolled: 91
# Lina Lapis rolled: 336
# No winner in this simulation.
#
# Simulation 14
# Shiwo Chrysalis rolled: 395
# Hale Draco rolled: 211
# Albatoss Balong rolled: 804
# Jovian Balong rolled: 319
# Elysia Kharim rolled: 984
# Luceth Marithine rolled: 721
# Suija Qualli rolled: 555
# Mozeo Oakden rolled: 411
# Maki Moonfire rolled: 350
# Apple Angelbow rolled: 422
# Deuce Halifax rolled: 290
# Mia Orange rolled: 77
# Rurvyn Reledran rolled: 548
# Sien Clark rolled: 883
# Lina Lapis rolled: 571
# No winner in this simulation.
#
# Simulation 15
# Shiwo Chrysalis rolled: 511
# Hale Draco rolled: 353
# Albatoss Balong rolled: 662
# Jovian Balong rolled: 824
# Elysia Kharim rolled: 347
# Luceth Marithine rolled: 236
# Suija Qualli rolled: 517
# Mozeo Oakden rolled: 826
# Maki Moonfire rolled: 208
# Apple Angelbow rolled: 383
# Deuce Halifax rolled: 125
# Mia Orange rolled: 498
# Rurvyn Reledran rolled: 605
# Sien Clark rolled: 586
# Lina Lapis rolled: 416
# No winner in this simulation.
#
# Simulation 16
# Shiwo Chrysalis rolled: 882
# Hale Draco rolled: 31
# Albatoss Balong rolled: 641
# Jovian Balong rolled: 998
# Elysia Kharim rolled: 761
# Luceth Marithine rolled: 286
# Suija Qualli rolled: 451
# Mozeo Oakden rolled: 338
# Maki Moonfire rolled: 821
# Apple Angelbow rolled: 570
# Deuce Halifax rolled: 56
# Mia Orange rolled: 721
# Rurvyn Reledran rolled: 823
# Sien Clark rolled: 185
# Lina Lapis rolled: 110
# No winner in this simulation.
#
# Simulation 17
# Shiwo Chrysalis rolled: 49
# Hale Draco rolled: 728
# Albatoss Balong rolled: 786
# Jovian Balong rolled: 725
# Elysia Kharim rolled: 882
# Luceth Marithine rolled: 931
# Suija Qualli rolled: 72
# Mozeo Oakden rolled: 984
# Maki Moonfire rolled: 370
# Apple Angelbow rolled: 245
# Deuce Halifax rolled: 359
# Mia Orange rolled: 190
# Rurvyn Reledran rolled: 752
# Sien Clark rolled: 86
# Lina Lapis rolled: 524
# No winner in this simulation.
#
# Simulation 18
# Shiwo Chrysalis rolled: 656
# Hale Draco rolled: 347
# Albatoss Balong rolled: 354
# Jovian Balong rolled: 188
# Elysia Kharim rolled: 469
# Luceth Marithine rolled: 608
# Suija Qualli rolled: 710
# Mozeo Oakden rolled: 799
# Maki Moonfire rolled: 801
# Apple Angelbow rolled: 6
# Deuce Halifax rolled: 487
# Mia Orange rolled: 654
# Rurvyn Reledran rolled: 507
# Sien Clark rolled: 73
# Lina Lapis rolled: 258
# No winner in this simulation.
#
# Simulation 19
# Shiwo Chrysalis rolled: 297
# Hale Draco rolled: 72
# Albatoss Balong rolled: 853
# Jovian Balong rolled: 763
# Elysia Kharim rolled: 12
# Luceth Marithine rolled: 141
# Suija Qualli rolled: 725
# Mozeo Oakden rolled: 371
# Maki Moonfire rolled: 558
# Apple Angelbow rolled: 403
# Deuce Halifax rolled: 551
# Mia Orange rolled: 286
# Rurvyn Reledran rolled: 896
# Sien Clark rolled: 539
# Lina Lapis rolled: 622
# No winner in this simulation.
#
# Simulation 20
# Shiwo Chrysalis rolled: 537
# Hale Draco rolled: 916
# Albatoss Balong rolled: 942
# Jovian Balong rolled: 546
# Elysia Kharim rolled: 958
# Luceth Marithine rolled: 152
# Suija Qualli rolled: 977
# Mozeo Oakden rolled: 970
# Maki Moonfire rolled: 236
# Apple Angelbow rolled: 770
# Deuce Halifax rolled: 353
# Mia Orange rolled: 423
# Rurvyn Reledran rolled: 166
# Sien Clark rolled: 749
# Lina Lapis rolled: 62
# No winner in this simulation.
#
# Simulation 21
# Shiwo Chrysalis rolled: 346
# Hale Draco rolled: 237
# Albatoss Balong rolled: 645
# Jovian Balong rolled: 404
# Elysia Kharim rolled: 677
# Luceth Marithine rolled: 780
# Suija Qualli rolled: 974
# Mozeo Oakden rolled: 579
# Maki Moonfire rolled: 415
# Apple Angelbow rolled: 314
# Deuce Halifax rolled: 371
# Mia Orange rolled: 339
# Rurvyn Reledran rolled: 294
# Sien Clark rolled: 494
# Lina Lapis rolled: 773
# No winner in this simulation.
#
# Simulation 22
# Shiwo Chrysalis rolled: 335
# Hale Draco rolled: 346
# Albatoss Balong rolled: 559
# Jovian Balong rolled: 970
# Elysia Kharim rolled: 956
# Luceth Marithine rolled: 169
# Suija Qualli rolled: 518
# Mozeo Oakden rolled: 552
# Maki Moonfire rolled: 668
# Apple Angelbow rolled: 676
# Deuce Halifax rolled: 75
# Mia Orange rolled: 376
# Rurvyn Reledran rolled: 775
# Sien Clark rolled: 511
# Lina Lapis rolled: 856
# No winner in this simulation.
#
# Simulation 23
# Shiwo Chrysalis rolled: 263
# Hale Draco rolled: 822
# Albatoss Balong rolled: 9
# Jovian Balong rolled: 807
# Elysia Kharim rolled: 396
# Luceth Marithine rolled: 912
# Suija Qualli rolled: 445
# Mozeo Oakden rolled: 596
# Maki Moonfire rolled: 417
# Apple Angelbow rolled: 674
# Deuce Halifax rolled: 340
# Mia Orange rolled: 440
# Rurvyn Reledran rolled: 484
# Sien Clark rolled: 728
# Lina Lapis rolled: 789
# No winner in this simulation.
#
# Simulation 24
# Shiwo Chrysalis rolled: 498
# Hale Draco rolled: 799
# Albatoss Balong rolled: 934
# Jovian Balong rolled: 824
# Elysia Kharim rolled: 247
# Luceth Marithine rolled: 309
# Suija Qualli rolled: 608
# Mozeo Oakden rolled: 291
# Maki Moonfire rolled: 186
# Apple Angelbow rolled: 864
# Deuce Halifax rolled: 890
# Mia Orange rolled: 238
# Rurvyn Reledran rolled: 180
# Sien Clark rolled: 193
# Lina Lapis rolled: 933
# No winner in this simulation.
#
# Simulation 25
# Shiwo Chrysalis rolled: 104
# Hale Draco rolled: 582
# Albatoss Balong rolled: 910
# Jovian Balong rolled: 478
# Elysia Kharim rolled: 780
# Luceth Marithine rolled: 508
# Suija Qualli rolled: 449
# Mozeo Oakden rolled: 778
# Maki Moonfire rolled: 899
# Apple Angelbow rolled: 717
# Deuce Halifax rolled: 749
# Mia Orange rolled: 117
# Rurvyn Reledran rolled: 929
# Sien Clark rolled: 883
# Lina Lapis rolled: 183
# No winner in this simulation.
#
# Simulation 26
# Shiwo Chrysalis rolled: 521
# Hale Draco rolled: 490
# Albatoss Balong rolled: 521
# Jovian Balong rolled: 591
# Elysia Kharim rolled: 216
# Luceth Marithine rolled: 340
# Suija Qualli rolled: 488
# Mozeo Oakden rolled: 324
# Maki Moonfire rolled: 935
# Apple Angelbow rolled: 574
# Deuce Halifax rolled: 437
# Mia Orange rolled: 804
# Rurvyn Reledran rolled: 180
# Sien Clark rolled: 919
# Lina Lapis rolled: 345
# No winner in this simulation.
#
# Simulation 27
# Shiwo Chrysalis rolled: 887
# Hale Draco rolled: 406
# Albatoss Balong rolled: 868
# Jovian Balong rolled: 93
# Elysia Kharim rolled: 9
# Luceth Marithine rolled: 626
# Suija Qualli rolled: 983
# Mozeo Oakden rolled: 424
# Maki Moonfire rolled: 950
# Apple Angelbow rolled: 344
# Deuce Halifax rolled: 873
# Mia Orange rolled: 173
# Rurvyn Reledran rolled: 261
# Sien Clark rolled: 252
# Lina Lapis rolled: 563
# No winner in this simulation.
#
# Simulation 28
# Shiwo Chrysalis rolled: 387
# Hale Draco rolled: 602
# Albatoss Balong rolled: 603
# Jovian Balong rolled: 905
# Elysia Kharim rolled: 761
# Luceth Marithine rolled: 316
# Suija Qualli rolled: 369
# Mozeo Oakden rolled: 290
# Maki Moonfire rolled: 862
# Apple Angelbow rolled: 60
# Deuce Halifax rolled: 362
# Mia Orange rolled: 808
# Rurvyn Reledran rolled: 386
# Sien Clark rolled: 499
# Lina Lapis rolled: 600
# No winner in this simulation.
#
# Simulation 29
# Shiwo Chrysalis rolled: 887
# Hale Draco rolled: 450
# Albatoss Balong rolled: 648
# Jovian Balong rolled: 51
# Elysia Kharim rolled: 334
# Luceth Marithine rolled: 648
# Suija Qualli rolled: 534
# Mozeo Oakden rolled: 858
# Maki Moonfire rolled: 600
# Apple Angelbow rolled: 575
# Deuce Halifax rolled: 165
# Mia Orange rolled: 379
# Rurvyn Reledran rolled: 966
# Sien Clark rolled: 544
# Lina Lapis rolled: 473
# No winner in this simulation.
#
# Simulation 30
# Shiwo Chrysalis rolled: 782
# Hale Draco rolled: 62
# Albatoss Balong rolled: 650
# Jovian Balong rolled: 253
# Elysia Kharim rolled: 238
# Luceth Marithine rolled: 492
# Suija Qualli rolled: 501
# Mozeo Oakden rolled: 383
# Maki Moonfire rolled: 642
# Apple Angelbow rolled: 136
# Deuce Halifax rolled: 71
# Mia Orange rolled: 988
# Rurvyn Reledran rolled: 159
# Sien Clark rolled: 140
# Lina Lapis rolled: 668
# No winner in this simulation.
#
# Simulation 31
# Shiwo Chrysalis rolled: 973
# Hale Draco rolled: 939
# Albatoss Balong rolled: 782
# Jovian Balong rolled: 478
# Elysia Kharim rolled: 237
# Luceth Marithine rolled: 896
# Suija Qualli rolled: 66
# Mozeo Oakden rolled: 56
# Maki Moonfire rolled: 731
# Apple Angelbow rolled: 578
# Deuce Halifax rolled: 724
# Mia Orange rolled: 107
# Rurvyn Reledran rolled: 1
# Sien Clark rolled: 957
# Lina Lapis rolled: 974
# No winner in this simulation.
#
# Simulation 32
# Shiwo Chrysalis rolled: 924
# Hale Draco rolled: 967
# Albatoss Balong rolled: 406
# Jovian Balong rolled: 388
# Elysia Kharim rolled: 76
# Luceth Marithine rolled: 74
# Suija Qualli rolled: 9
# Mozeo Oakden rolled: 910
# Maki Moonfire rolled: 10
# Apple Angelbow rolled: 338
# Deuce Halifax rolled: 761
# Mia Orange rolled: 360
# Rurvyn Reledran rolled: 250
# Sien Clark rolled: 227
# Lina Lapis rolled: 760
# No winner in this simulation.
#
# Simulation 33
# Shiwo Chrysalis rolled: 990
# Hale Draco rolled: 156
# Albatoss Balong rolled: 217
# Jovian Balong rolled: 145
# Elysia Kharim rolled: 297
# Luceth Marithine rolled: 647
# Suija Qualli rolled: 207
# Mozeo Oakden rolled: 452
# Maki Moonfire rolled: 193
# Apple Angelbow rolled: 361
# Deuce Halifax rolled: 951
# Mia Orange rolled: 141
# Rurvyn Reledran rolled: 446
# Sien Clark rolled: 778
# Lina Lapis rolled: 699
# No winner in this simulation.
#
# Simulation 34
# Shiwo Chrysalis rolled: 916
# Hale Draco rolled: 880
# Albatoss Balong rolled: 600
# Jovian Balong rolled: 238
# Elysia Kharim rolled: 454
# Luceth Marithine rolled: 880
# Suija Qualli rolled: 925
# Mozeo Oakden rolled: 866
# Maki Moonfire rolled: 32
# Apple Angelbow rolled: 973
# Deuce Halifax rolled: 446
# Mia Orange rolled: 336
# Rurvyn Reledran rolled: 386
# Sien Clark rolled: 632
# Lina Lapis rolled: 525
# No winner in this simulation.
#
# Simulation 35
# Shiwo Chrysalis rolled: 898
# Hale Draco rolled: 421
# Albatoss Balong rolled: 457
# Jovian Balong rolled: 592
# Elysia Kharim rolled: 607
# Luceth Marithine rolled: 812
# Suija Qualli rolled: 277
# Mozeo Oakden rolled: 373
# Maki Moonfire rolled: 89
# Apple Angelbow rolled: 176
# Deuce Halifax rolled: 713
# Mia Orange rolled: 687
# Rurvyn Reledran rolled: 886
# Sien Clark rolled: 680
# Lina Lapis rolled: 528
# No winner in this simulation.
#
# Simulation 36
# Shiwo Chrysalis rolled: 253
# Hale Draco rolled: 954
# Albatoss Balong rolled: 285
# Jovian Balong rolled: 804
# Elysia Kharim rolled: 907
# Luceth Marithine rolled: 309
# Suija Qualli rolled: 625
# Mozeo Oakden rolled: 366
# Maki Moonfire rolled: 829
# Apple Angelbow rolled: 474
# Deuce Halifax rolled: 251
# Mia Orange rolled: 929
# Rurvyn Reledran rolled: 560
# Sien Clark rolled: 324
# Lina Lapis rolled: 939
# No winner in this simulation.
#
# Simulation 37
# Shiwo Chrysalis rolled: 866
# Hale Draco rolled: 794
# Albatoss Balong rolled: 731
# Jovian Balong rolled: 160
# Elysia Kharim rolled: 186
# Luceth Marithine rolled: 888
# Suija Qualli rolled: 641
# Mozeo Oakden rolled: 695
# Maki Moonfire rolled: 12
# Apple Angelbow rolled: 968
# Deuce Halifax rolled: 682
# Mia Orange rolled: 951
# Rurvyn Reledran rolled: 907
# Sien Clark rolled: 633
# Lina Lapis rolled: 281
# No winner in this simulation.
#
# Simulation 38
# Shiwo Chrysalis rolled: 67
# Hale Draco rolled: 454
# Albatoss Balong rolled: 495
# Jovian Balong rolled: 311
# Elysia Kharim rolled: 807
# Luceth Marithine rolled: 531
# Suija Qualli rolled: 290
# Mozeo Oakden rolled: 239
# Maki Moonfire rolled: 897
# Apple Angelbow rolled: 38
# Deuce Halifax rolled: 792
# Mia Orange rolled: 138
# Rurvyn Reledran rolled: 181
# Sien Clark rolled: 566
# Lina Lapis rolled: 802
# No winner in this simulation.
#
# Simulation 39
# Shiwo Chrysalis rolled: 949
# Hale Draco rolled: 622
# Albatoss Balong rolled: 559
# Jovian Balong rolled: 624
# Elysia Kharim rolled: 640
# Luceth Marithine rolled: 431
# Suija Qualli rolled: 315
# Mozeo Oakden rolled: 567
# Maki Moonfire rolled: 10
# Apple Angelbow rolled: 723
# Deuce Halifax rolled: 416
# Mia Orange rolled: 904
# Rurvyn Reledran rolled: 156
# Sien Clark rolled: 69
# Lina Lapis rolled: 760
# No winner in this simulation.
#
# Simulation 40
# Shiwo Chrysalis rolled: 888
# Hale Draco rolled: 378
# Albatoss Balong rolled: 775
# Jovian Balong rolled: 316
# Elysia Kharim rolled: 993
# Luceth Marithine rolled: 140
# Suija Qualli rolled: 857
# Mozeo Oakden rolled: 837
# Maki Moonfire rolled: 424
# Apple Angelbow rolled: 864
# Deuce Halifax rolled: 740
# Mia Orange rolled: 397
# Rurvyn Reledran rolled: 371
# Sien Clark rolled: 297
# Lina Lapis rolled: 404
# No winner in this simulation.
#
# Simulation 41
# Shiwo Chrysalis rolled: 246
# Hale Draco rolled: 973
# Albatoss Balong rolled: 207
# Jovian Balong rolled: 834
# Elysia Kharim rolled: 560
# Luceth Marithine rolled: 629
# Suija Qualli rolled: 344
# Mozeo Oakden rolled: 118
# Maki Moonfire rolled: 288
# Apple Angelbow rolled: 90
# Deuce Halifax rolled: 4
# Mia Orange rolled: 841
# Rurvyn Reledran rolled: 794
# Sien Clark rolled: 640
# Lina Lapis rolled: 891
# No winner in this simulation.
#
# Simulation 42
# Shiwo Chrysalis rolled: 384
# Hale Draco rolled: 374
# Albatoss Balong rolled: 455
# Jovian Balong rolled: 599
# Elysia Kharim rolled: 261
# Luceth Marithine rolled: 901
# Suija Qualli rolled: 666
# Mozeo Oakden rolled: 810
# Maki Moonfire rolled: 526
# Apple Angelbow rolled: 134
# Deuce Halifax rolled: 662
# Mia Orange rolled: 755
# Rurvyn Reledran rolled: 803
# Sien Clark rolled: 90
# Lina Lapis rolled: 315
# No winner in this simulation.
#
# Simulation 43
# Shiwo Chrysalis rolled: 10
# Hale Draco rolled: 167
# Albatoss Balong rolled: 253
# Jovian Balong rolled: 630
# Elysia Kharim rolled: 344
# Luceth Marithine rolled: 491
# Suija Qualli rolled: 746
# Mozeo Oakden rolled: 989
# Maki Moonfire rolled: 434
# Apple Angelbow rolled: 851
# Deuce Halifax rolled: 954
# Mia Orange rolled: 165
# Rurvyn Reledran rolled: 669
# Sien Clark rolled: 819
# Lina Lapis rolled: 153
# No winner in this simulation.
#
# Simulation 44
# Shiwo Chrysalis rolled: 255
# Hale Draco rolled: 565
# Albatoss Balong rolled: 28
# Jovian Balong rolled: 308
# Elysia Kharim rolled: 167
# Luceth Marithine rolled: 219
# Suija Qualli rolled: 493
# Mozeo Oakden rolled: 380
# Maki Moonfire rolled: 300
# Apple Angelbow rolled: 718
# Deuce Halifax rolled: 931
# Mia Orange rolled: 135
# Rurvyn Reledran rolled: 48
# Sien Clark rolled: 721
# Lina Lapis rolled: 943
# No winner in this simulation.
#
# Simulation 45
# Shiwo Chrysalis rolled: 296
# Hale Draco rolled: 320
# Albatoss Balong rolled: 636
# Jovian Balong rolled: 610
# Elysia Kharim rolled: 137
# Luceth Marithine rolled: 552
# Suija Qualli rolled: 426
# Mozeo Oakden rolled: 284
# Maki Moonfire rolled: 236
# Apple Angelbow rolled: 908
# Deuce Halifax rolled: 235
# Mia Orange rolled: 363
# Rurvyn Reledran rolled: 861
# Sien Clark rolled: 758
# Lina Lapis rolled: 682
# No winner in this simulation.
#
# Simulation 46
# Shiwo Chrysalis rolled: 500
# Hale Draco rolled: 945
# Albatoss Balong rolled: 772
# Jovian Balong rolled: 459
# Elysia Kharim rolled: 188
# Luceth Marithine rolled: 273
# Suija Qualli rolled: 770
# Mozeo Oakden rolled: 931
# Maki Moonfire rolled: 568
# Apple Angelbow rolled: 750
# Deuce Halifax rolled: 383
# Mia Orange rolled: 381
# Rurvyn Reledran rolled: 661
# Sien Clark rolled: 805
# Lina Lapis rolled: 373
# No winner in this simulation.
#
# Simulation 47
# Shiwo Chrysalis rolled: 668
# Hale Draco rolled: 955
# Albatoss Balong rolled: 364
# Jovian Balong rolled: 829
# Elysia Kharim rolled: 458
# Luceth Marithine rolled: 913
# Suija Qualli rolled: 543
# Mozeo Oakden rolled: 859
# Maki Moonfire rolled: 45
# Apple Angelbow rolled: 105
# Deuce Halifax rolled: 759
# Mia Orange rolled: 248
# Rurvyn Reledran rolled: 16
# Sien Clark rolled: 450
# Lina Lapis rolled: 578
# No winner in this simulation.
#
# Simulation 48
# Shiwo Chrysalis rolled: 57
# Hale Draco rolled: 478
# Albatoss Balong rolled: 516
# Jovian Balong rolled: 883
# Elysia Kharim rolled: 977
# Luceth Marithine rolled: 717
# Suija Qualli rolled: 895
# Mozeo Oakden rolled: 885
# Maki Moonfire rolled: 447
# Apple Angelbow rolled: 546
# Deuce Halifax rolled: 205
# Mia Orange rolled: 460
# Rurvyn Reledran rolled: 215
# Sien Clark rolled: 639
# Lina Lapis rolled: 522
# No winner in this simulation.
#
# Simulation 49
# Shiwo Chrysalis rolled: 376
# Hale Draco rolled: 527
# Albatoss Balong rolled: 147
# Jovian Balong rolled: 179
# Elysia Kharim rolled: 266
# Luceth Marithine rolled: 44
# Suija Qualli rolled: 923
# Mozeo Oakden rolled: 163
# Maki Moonfire rolled: 959
# Apple Angelbow rolled: 496
# Deuce Halifax rolled: 792
# Mia Orange rolled: 994
# Rurvyn Reledran rolled: 572
# Sien Clark rolled: 641
# Lina Lapis rolled: 254
# No winner in this simulation.
#
# Simulation 50
# Shiwo Chrysalis rolled: 134
# Hale Draco rolled: 969
# Albatoss Balong rolled: 310
# Jovian Balong rolled: 430
# Elysia Kharim rolled: 99
# Luceth Marithine rolled: 180
# Suija Qualli rolled: 654
# Mozeo Oakden rolled: 316
# Maki Moonfire rolled: 236
# Apple Angelbow rolled: 185
# Deuce Halifax rolled: 352
# Mia Orange rolled: 602
# Rurvyn Reledran rolled: 74
# Sien Clark rolled: 739
# Lina Lapis rolled: 944
# No winner in this simulation.
#
# Simulation 51
# Shiwo Chrysalis rolled: 555
# Hale Draco rolled: 910
# Albatoss Balong rolled: 755
# Jovian Balong rolled: 202
# Elysia Kharim rolled: 33
# Luceth Marithine rolled: 387
# Suija Qualli rolled: 10
# Mozeo Oakden rolled: 509
# Maki Moonfire rolled: 652
# Apple Angelbow rolled: 409
# Deuce Halifax rolled: 510
# Mia Orange rolled: 392
# Rurvyn Reledran rolled: 724
# Sien Clark rolled: 148
# Lina Lapis rolled: 51
# No winner in this simulation.
#
# Simulation 52
# Shiwo Chrysalis rolled: 407
# Hale Draco rolled: 460
# Albatoss Balong rolled: 570
# Jovian Balong rolled: 285
# Elysia Kharim rolled: 684
# Luceth Marithine rolled: 141
# Suija Qualli rolled: 191
# Mozeo Oakden rolled: 570
# Maki Moonfire rolled: 463
# Apple Angelbow rolled: 399
# Deuce Halifax rolled: 877
# Mia Orange rolled: 737
# Rurvyn Reledran rolled: 812
# Sien Clark rolled: 801
# Lina Lapis rolled: 193
# No winner in this simulation.
#
# Simulation 53
# Shiwo Chrysalis rolled: 328
# Hale Draco rolled: 878
# Albatoss Balong rolled: 833
# Jovian Balong rolled: 301
# Elysia Kharim rolled: 573
# Luceth Marithine rolled: 958
# Suija Qualli rolled: 685
# Mozeo Oakden rolled: 395
# Maki Moonfire rolled: 56
# Apple Angelbow rolled: 119
# Deuce Halifax rolled: 881
# Mia Orange rolled: 99
# Rurvyn Reledran rolled: 203
# Sien Clark rolled: 964
# Lina Lapis rolled: 191
# No winner in this simulation.
#
# Simulation 54
# Shiwo Chrysalis rolled: 22
# Hale Draco rolled: 722
# Albatoss Balong rolled: 524
# Jovian Balong rolled: 542
# Elysia Kharim rolled: 933
# Luceth Marithine rolled: 166
# Suija Qualli rolled: 864
# Mozeo Oakden rolled: 242
# Maki Moonfire rolled: 272
# Apple Angelbow rolled: 32
# Deuce Halifax rolled: 12
# Mia Orange rolled: 498
# Rurvyn Reledran rolled: 234
# Sien Clark rolled: 211
# Lina Lapis rolled: 138
# No winner in this simulation.
#
# Simulation 55
# Shiwo Chrysalis rolled: 314
# Hale Draco rolled: 167
# Albatoss Balong rolled: 828
# Jovian Balong rolled: 439
# Elysia Kharim rolled: 253
# Luceth Marithine rolled: 561
# Suija Qualli rolled: 942
# Mozeo Oakden rolled: 446
# Maki Moonfire rolled: 92
# Apple Angelbow rolled: 863
# Deuce Halifax rolled: 935
# Mia Orange rolled: 302
# Rurvyn Reledran rolled: 970
# Sien Clark rolled: 219
# Lina Lapis rolled: 943
# No winner in this simulation.
#
# Simulation 56
# Shiwo Chrysalis rolled: 579
# Hale Draco rolled: 701
# Albatoss Balong rolled: 177
# Jovian Balong rolled: 372
# Elysia Kharim rolled: 953
# Luceth Marithine rolled: 513
# Suija Qualli rolled: 217
# Mozeo Oakden rolled: 569
# Maki Moonfire rolled: 693
# Apple Angelbow rolled: 324
# Deuce Halifax rolled: 337
# Mia Orange rolled: 940
# Rurvyn Reledran rolled: 546
# Sien Clark rolled: 706
# Lina Lapis rolled: 603
# No winner in this simulation.
#
# Simulation 57
# Shiwo Chrysalis rolled: 23
# Hale Draco rolled: 258
# Albatoss Balong rolled: 962
# Jovian Balong rolled: 851
# Elysia Kharim rolled: 120
# Luceth Marithine rolled: 562
# Suija Qualli rolled: 86
# Mozeo Oakden rolled: 359
# Maki Moonfire rolled: 834
# Apple Angelbow rolled: 425
# Deuce Halifax rolled: 197
# Mia Orange rolled: 648
# Rurvyn Reledran rolled: 387
# Sien Clark rolled: 948
# Lina Lapis rolled: 487
# No winner in this simulation.
#
# Simulation 58
# Shiwo Chrysalis rolled: 539
# Hale Draco rolled: 767
# Albatoss Balong rolled: 161
# Jovian Balong rolled: 592
# Elysia Kharim rolled: 823
# Luceth Marithine rolled: 675
# Suija Qualli rolled: 56
# Mozeo Oakden rolled: 371
# Maki Moonfire rolled: 731
# Apple Angelbow rolled: 354
# Deuce Halifax rolled: 239
# Mia Orange rolled: 926
# Rurvyn Reledran rolled: 812
# Sien Clark rolled: 363
# Lina Lapis rolled: 755
# No winner in this simulation.
#
# Simulation 59
# Shiwo Chrysalis rolled: 44
# Hale Draco rolled: 630
# Albatoss Balong rolled: 553
# Jovian Balong rolled: 577
# Elysia Kharim rolled: 801
# Luceth Marithine rolled: 946
# Suija Qualli rolled: 940
# Mozeo Oakden rolled: 331
# Maki Moonfire rolled: 603
# Apple Angelbow rolled: 346
# Deuce Halifax rolled: 64
# Mia Orange rolled: 531
# Rurvyn Reledran rolled: 379
# Sien Clark rolled: 277
# Lina Lapis rolled: 621
# No winner in this simulation.
#
# Simulation 60
# Shiwo Chrysalis rolled: 638
# Hale Draco rolled: 276
# Albatoss Balong rolled: 407
# Jovian Balong rolled: 631
# Elysia Kharim rolled: 889
# Luceth Marithine rolled: 777
#
# Luceth Marithine wins the Dawntrail raffle with the number 777!
# <img src="https://img2.finalfantasyxiv.com/f/bd4029e8997af0946f84db2aace6a597_4d9be17b5e1edc617052b4dbf4007875fl0_640x873.jpg?1719509389"/>
# <h2>Winning FC Member Details</h2><table><tr><th>Details</th></tr><tr><td>Race/Clan/Gender</td></tr><tr><td>Au Ra</td></tr><tr><td>Raen / ♀</td></tr><tr><td>Nameday</td></tr><tr><td>25th Sun of the 1st Astral Moon</td></tr><tr><td>Guardian</td></tr><tr><td>Byregot, the Builder</td></tr><tr><td>City-state</td></tr><tr><td>Gridania</td></tr><tr><td>Grand Company</td></tr><tr><td>Maelstrom / Storm Captain</td></tr><tr><td>Free Company</td></tr><tr><td>Nerve</td></tr><tr><td>Attributes</td></tr></table>
# <h2>Simulation Statistics</h2><table><tr><th>Statistic</th><th>Value</th></tr><tr><td>Total Simulations</td><td>60</td></tr><tr><td>Total Winners</td><td>1</td></tr></table>
# <h2>Closest FC Members to Winning Number</h2><table><tr><th>Member</th><th>Total Count</th></tr><tr><td>Maki Moonfire</td><td>1</td></tr><tr><td>Suija Qualli</td><td>2</td></tr><tr><td>Albatoss Balong</td><td>4</td></tr><tr><td>Apple Angelbow</td><td>1</td></tr><tr><td>Luceth Marithine</td><td>2</td></tr><tr><td>Lina Lapis</td><td>1</td></tr><tr><td>Rurvyn Reledran</td><td>1</td></tr><tr><td>Elysia Kharim</td><td>1</td></tr><tr><td>Mozeo Oakden</td><td>1</td></tr><tr><td>Shiwo Chrysalis</td><td>1</td></tr><tr><td>Sien Clark</td><td>1</td></tr><tr><td>Hale Draco</td><td>1</td></tr></table>
