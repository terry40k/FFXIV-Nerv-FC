# %%
import requests
from bs4 import BeautifulSoup
import random
from IPython.display import display, Image, HTML
from collections import defaultdict

# Updated list of Nerv FC members in the drawing
fc_members = [
    "Shiwo Chrysalis", "Hale Draco", "Albatross Balong", "Jovian Balong", "Elysia Kharim", 
    "Luceth Marithine", "Suija Qualli", "Mozeo Oakden", "Maki Moonfire", "Apple Angelbow", 
    "Deuce Halifax", "Mia Orange", "Rurvyn Reledran", "Sien Clark"
]

# Function to fetch character profile image and details from FFXIV Lodestone
def get_character_info(name):
    search_url = f"https://na.finalfantasyxiv.com/lodestone/character/?q={name.replace(' ', '+')}&worldname=Lamia"
    response = requests.get(search_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Attempt to find the character profile link
    character_link = soup.find('a', class_='entry__link')
    if not character_link:
        print(f"Could not find character profile for {name} on Lamia")
        return None, None

    character_url = f"https://na.finalfantasyxiv.com{character_link['href']}"
    response = requests.get(character_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Attempt to find the profile image
    image_tag = soup.find('div', class_='character__detail__image')
    if not image_tag:
        print(f"Could not find profile image for {name}")
        return None, None

    image_url = image_tag.find('img')['src']

    # Attempt to find additional character details
    details_tag = soup.find('div', class_='character__profile__data')
    if details_tag:
        details = details_tag.get_text(strip=True, separator='\n').split('\n')
    else:
        details = ["Details not found."]

    return image_url, details

# Function to create HTML table for character details
def create_details_table(details):
    table_html = "<h2>Winning FC Member Details</h2><table><tr><th>Details</th></tr>"
    for detail in details:
        table_html += f"<tr><td>{detail}</td></tr>"
        if "Attributes" in detail:
            break
    table_html += "</table>"
    return table_html

# Function to create HTML table for closest members
def create_closest_table(closest_members):
    table_html = "<h2>Closest FC Members</h2><table><tr><th>Member</th><th>Rolled Number</th><th>Difference</th></tr>"
    for member, roll, diff in closest_members:
        table_html += f"<tr><td>{member}</td><td>{roll}</td><td>{diff}</td></tr>"
    table_html += "</table>"
    return table_html

# Function to display statistics
def display_statistics(simulation_count, winners):
    stats_html = "<h2>Simulation Statistics</h2><table><tr><th>Statistic</th><th>Value</th></tr>"
    stats_html += f"<tr><td>Total Simulations</td><td>{simulation_count}</td></tr>"
    stats_html += f"<tr><td>Total Winners</td><td>{len(winners)}</td></tr>"
    stats_html += "</table>"
    display(HTML(stats_html))

# Function to run the simulations
def run_simulations():
    winning_number = int(input("Enter the winning number (between 1 and 999): "))
    
    # Validate the input number
    if winning_number < 1 or winning_number > 999:
        print("The number must be between 1 and 999.")
        return
    
    simulation_count = 0
    winners = []
    closest_members = []

    for i in range(100):
        simulation_count += 1
        print(f"\nSimulation {i+1}")
        closest_roll = None
        closest_diff = float('inf')
        closest_member = None

        for fc_member in fc_members:
            rolled_number = random.randint(1, 999)
            print(f"{fc_member} rolled: {rolled_number}")
            diff = abs(rolled_number - winning_number)
            if diff < closest_diff:
                closest_diff = diff
                closest_roll = rolled_number
                closest_member = fc_member

            if rolled_number == winning_number:
                image_url, details = get_character_info(fc_member)
                if image_url:
                    print(f"\n{fc_member} wins the Dawntrail raffle with the number {winning_number}!\n")
                    display(Image(url=image_url))
                    details_table = create_details_table(details)
                    display(HTML(details_table))
                    winners.append(fc_member)
                    display_statistics(simulation_count, winners)
                    closest_table = create_closest_table(closest_members)
                    display(HTML(closest_table))
                    return

        closest_members.append((closest_member, closest_roll, closest_diff))
        print("No winner in this simulation.")
    
    # Display final statistics and closest members
    display_statistics(simulation_count, winners)
    closest_table = create_closest_table(closest_members)
    display(HTML(closest_table))

# Run the simulations
run_simulations()
# Out:
# Enter the winning number (between 1 and 999):  777
# Simulation 1
# Shiwo Chrysalis rolled: 206
# Hale Draco rolled: 996
# Albatross Balong rolled: 351
# Jovian Balong rolled: 302
# Elysia Kharim rolled: 820
# Luceth Marithine rolled: 750
# Suija Qualli rolled: 943
# Mozeo Oakden rolled: 134
# Maki Moonfire rolled: 679
# Apple Angelbow rolled: 171
# Deuce Halifax rolled: 257
# Mia Orange rolled: 244
# Rurvyn Reledran rolled: 187
# Sien Clark rolled: 192
# No winner in this simulation.
#
# Simulation 2
# Shiwo Chrysalis rolled: 10
# Hale Draco rolled: 156
# Albatross Balong rolled: 488
# Jovian Balong rolled: 450
# Elysia Kharim rolled: 638
# Luceth Marithine rolled: 869
# Suija Qualli rolled: 315
# Mozeo Oakden rolled: 346
# Maki Moonfire rolled: 76
# Apple Angelbow rolled: 400
# Deuce Halifax rolled: 399
# Mia Orange rolled: 833
# Rurvyn Reledran rolled: 949
# Sien Clark rolled: 364
# No winner in this simulation.
#
# Simulation 3
# Shiwo Chrysalis rolled: 477
# Hale Draco rolled: 848
# Albatross Balong rolled: 411
# Jovian Balong rolled: 451
# Elysia Kharim rolled: 855
# Luceth Marithine rolled: 336
# Suija Qualli rolled: 511
# Mozeo Oakden rolled: 615
# Maki Moonfire rolled: 213
# Apple Angelbow rolled: 301
# Deuce Halifax rolled: 782
# Mia Orange rolled: 911
# Rurvyn Reledran rolled: 451
# Sien Clark rolled: 741
# No winner in this simulation.
#
# Simulation 4
# Shiwo Chrysalis rolled: 510
# Hale Draco rolled: 533
# Albatross Balong rolled: 891
# Jovian Balong rolled: 529
# Elysia Kharim rolled: 929
# Luceth Marithine rolled: 486
# Suija Qualli rolled: 706
# Mozeo Oakden rolled: 15
# Maki Moonfire rolled: 655
# Apple Angelbow rolled: 624
# Deuce Halifax rolled: 530
# Mia Orange rolled: 373
# Rurvyn Reledran rolled: 502
# Sien Clark rolled: 718
# No winner in this simulation.
#
# Simulation 5
# Shiwo Chrysalis rolled: 64
# Hale Draco rolled: 195
# Albatross Balong rolled: 459
# Jovian Balong rolled: 127
# Elysia Kharim rolled: 995
# Luceth Marithine rolled: 921
# Suija Qualli rolled: 243
# Mozeo Oakden rolled: 499
# Maki Moonfire rolled: 82
# Apple Angelbow rolled: 758
# Deuce Halifax rolled: 142
# Mia Orange rolled: 334
# Rurvyn Reledran rolled: 907
# Sien Clark rolled: 181
# No winner in this simulation.
#
# Simulation 6
# Shiwo Chrysalis rolled: 753
# Hale Draco rolled: 606
# Albatross Balong rolled: 863
# Jovian Balong rolled: 294
# Elysia Kharim rolled: 517
# Luceth Marithine rolled: 353
# Suija Qualli rolled: 456
# Mozeo Oakden rolled: 164
# Maki Moonfire rolled: 330
# Apple Angelbow rolled: 495
# Deuce Halifax rolled: 193
# Mia Orange rolled: 492
# Rurvyn Reledran rolled: 579
# Sien Clark rolled: 439
# No winner in this simulation.
#
# Simulation 7
# Shiwo Chrysalis rolled: 451
# Hale Draco rolled: 165
# Albatross Balong rolled: 897
# Jovian Balong rolled: 546
# Elysia Kharim rolled: 657
# Luceth Marithine rolled: 578
# Suija Qualli rolled: 270
# Mozeo Oakden rolled: 796
# Maki Moonfire rolled: 56
# Apple Angelbow rolled: 159
# Deuce Halifax rolled: 512
# Mia Orange rolled: 920
# Rurvyn Reledran rolled: 476
# Sien Clark rolled: 456
# No winner in this simulation.
#
# Simulation 8
# Shiwo Chrysalis rolled: 590
# Hale Draco rolled: 807
# Albatross Balong rolled: 88
# Jovian Balong rolled: 865
# Elysia Kharim rolled: 749
# Luceth Marithine rolled: 605
# Suija Qualli rolled: 477
# Mozeo Oakden rolled: 665
# Maki Moonfire rolled: 5
# Apple Angelbow rolled: 611
# Deuce Halifax rolled: 750
# Mia Orange rolled: 468
# Rurvyn Reledran rolled: 156
# Sien Clark rolled: 969
# No winner in this simulation.
#
# Simulation 9
# Shiwo Chrysalis rolled: 358
# Hale Draco rolled: 878
# Albatross Balong rolled: 802
# Jovian Balong rolled: 746
# Elysia Kharim rolled: 944
# Luceth Marithine rolled: 470
# Suija Qualli rolled: 707
# Mozeo Oakden rolled: 741
# Maki Moonfire rolled: 557
# Apple Angelbow rolled: 811
# Deuce Halifax rolled: 69
# Mia Orange rolled: 540
# Rurvyn Reledran rolled: 889
# Sien Clark rolled: 352
# No winner in this simulation.
#
# Simulation 10
# Shiwo Chrysalis rolled: 268
# Hale Draco rolled: 762
# Albatross Balong rolled: 153
# Jovian Balong rolled: 125
# Elysia Kharim rolled: 732
# Luceth Marithine rolled: 784
# Suija Qualli rolled: 917
# Mozeo Oakden rolled: 178
# Maki Moonfire rolled: 541
# Apple Angelbow rolled: 47
# Deuce Halifax rolled: 150
# Mia Orange rolled: 343
# Rurvyn Reledran rolled: 658
# Sien Clark rolled: 80
# No winner in this simulation.
#
# Simulation 11
# Shiwo Chrysalis rolled: 612
# Hale Draco rolled: 141
# Albatross Balong rolled: 219
# Jovian Balong rolled: 592
# Elysia Kharim rolled: 629
# Luceth Marithine rolled: 286
# Suija Qualli rolled: 383
# Mozeo Oakden rolled: 77
# Maki Moonfire rolled: 773
# Apple Angelbow rolled: 882
# Deuce Halifax rolled: 787
# Mia Orange rolled: 737
# Rurvyn Reledran rolled: 123
# Sien Clark rolled: 809
# No winner in this simulation.
#
# Simulation 12
# Shiwo Chrysalis rolled: 663
# Hale Draco rolled: 556
# Albatross Balong rolled: 732
# Jovian Balong rolled: 449
# Elysia Kharim rolled: 315
# Luceth Marithine rolled: 491
# Suija Qualli rolled: 999
# Mozeo Oakden rolled: 15
# Maki Moonfire rolled: 122
# Apple Angelbow rolled: 968
# Deuce Halifax rolled: 229
# Mia Orange rolled: 377
# Rurvyn Reledran rolled: 442
# Sien Clark rolled: 790
# No winner in this simulation.
#
# Simulation 13
# Shiwo Chrysalis rolled: 783
# Hale Draco rolled: 648
# Albatross Balong rolled: 806
# Jovian Balong rolled: 526
# Elysia Kharim rolled: 934
# Luceth Marithine rolled: 533
# Suija Qualli rolled: 856
# Mozeo Oakden rolled: 30
# Maki Moonfire rolled: 221
# Apple Angelbow rolled: 754
# Deuce Halifax rolled: 134
# Mia Orange rolled: 23
# Rurvyn Reledran rolled: 757
# Sien Clark rolled: 920
# No winner in this simulation.
#
# Simulation 14
# Shiwo Chrysalis rolled: 800
# Hale Draco rolled: 87
# Albatross Balong rolled: 89
# Jovian Balong rolled: 99
# Elysia Kharim rolled: 631
# Luceth Marithine rolled: 567
# Suija Qualli rolled: 206
# Mozeo Oakden rolled: 541
# Maki Moonfire rolled: 279
# Apple Angelbow rolled: 818
# Deuce Halifax rolled: 607
# Mia Orange rolled: 739
# Rurvyn Reledran rolled: 727
# Sien Clark rolled: 63
# No winner in this simulation.
#
# Simulation 15
# Shiwo Chrysalis rolled: 617
# Hale Draco rolled: 789
# Albatross Balong rolled: 720
# Jovian Balong rolled: 675
# Elysia Kharim rolled: 504
# Luceth Marithine rolled: 389
# Suija Qualli rolled: 534
# Mozeo Oakden rolled: 555
# Maki Moonfire rolled: 405
# Apple Angelbow rolled: 462
# Deuce Halifax rolled: 934
# Mia Orange rolled: 831
# Rurvyn Reledran rolled: 329
# Sien Clark rolled: 569
# No winner in this simulation.
#
# Simulation 16
# Shiwo Chrysalis rolled: 924
# Hale Draco rolled: 600
# Albatross Balong rolled: 410
# Jovian Balong rolled: 159
# Elysia Kharim rolled: 108
# Luceth Marithine rolled: 306
# Suija Qualli rolled: 807
# Mozeo Oakden rolled: 566
# Maki Moonfire rolled: 930
# Apple Angelbow rolled: 504
# Deuce Halifax rolled: 998
# Mia Orange rolled: 794
# Rurvyn Reledran rolled: 184
# Sien Clark rolled: 648
# No winner in this simulation.
#
# Simulation 17
# Shiwo Chrysalis rolled: 775
# Hale Draco rolled: 397
# Albatross Balong rolled: 957
# Jovian Balong rolled: 311
# Elysia Kharim rolled: 546
# Luceth Marithine rolled: 659
# Suija Qualli rolled: 692
# Mozeo Oakden rolled: 983
# Maki Moonfire rolled: 587
# Apple Angelbow rolled: 155
# Deuce Halifax rolled: 944
# Mia Orange rolled: 253
# Rurvyn Reledran rolled: 389
# Sien Clark rolled: 609
# No winner in this simulation.
#
# Simulation 18
# Shiwo Chrysalis rolled: 443
# Hale Draco rolled: 614
# Albatross Balong rolled: 446
# Jovian Balong rolled: 746
# Elysia Kharim rolled: 934
# Luceth Marithine rolled: 78
# Suija Qualli rolled: 517
# Mozeo Oakden rolled: 901
# Maki Moonfire rolled: 572
# Apple Angelbow rolled: 371
# Deuce Halifax rolled: 655
# Mia Orange rolled: 83
# Rurvyn Reledran rolled: 886
# Sien Clark rolled: 2
# No winner in this simulation.
#
# Simulation 19
# Shiwo Chrysalis rolled: 487
# Hale Draco rolled: 317
# Albatross Balong rolled: 120
# Jovian Balong rolled: 866
# Elysia Kharim rolled: 936
# Luceth Marithine rolled: 106
# Suija Qualli rolled: 451
# Mozeo Oakden rolled: 368
# Maki Moonfire rolled: 133
# Apple Angelbow rolled: 272
# Deuce Halifax rolled: 425
# Mia Orange rolled: 644
# Rurvyn Reledran rolled: 731
# Sien Clark rolled: 401
# No winner in this simulation.
#
# Simulation 20
# Shiwo Chrysalis rolled: 249
# Hale Draco rolled: 469
# Albatross Balong rolled: 326
# Jovian Balong rolled: 412
# Elysia Kharim rolled: 750
# Luceth Marithine rolled: 675
# Suija Qualli rolled: 160
# Mozeo Oakden rolled: 307
# Maki Moonfire rolled: 64
# Apple Angelbow rolled: 172
# Deuce Halifax rolled: 959
# Mia Orange rolled: 826
# Rurvyn Reledran rolled: 769
# Sien Clark rolled: 468
# No winner in this simulation.
#
# Simulation 21
# Shiwo Chrysalis rolled: 294
# Hale Draco rolled: 393
# Albatross Balong rolled: 357
# Jovian Balong rolled: 111
# Elysia Kharim rolled: 869
# Luceth Marithine rolled: 817
# Suija Qualli rolled: 504
# Mozeo Oakden rolled: 871
# Maki Moonfire rolled: 151
# Apple Angelbow rolled: 524
# Deuce Halifax rolled: 534
# Mia Orange rolled: 984
# Rurvyn Reledran rolled: 685
# Sien Clark rolled: 984
# No winner in this simulation.
#
# Simulation 22
# Shiwo Chrysalis rolled: 336
# Hale Draco rolled: 374
# Albatross Balong rolled: 452
# Jovian Balong rolled: 590
# Elysia Kharim rolled: 741
# Luceth Marithine rolled: 157
# Suija Qualli rolled: 62
# Mozeo Oakden rolled: 680
# Maki Moonfire rolled: 683
# Apple Angelbow rolled: 24
# Deuce Halifax rolled: 567
# Mia Orange rolled: 455
# Rurvyn Reledran rolled: 86
# Sien Clark rolled: 679
# No winner in this simulation.
#
# Simulation 23
# Shiwo Chrysalis rolled: 414
# Hale Draco rolled: 349
# Albatross Balong rolled: 726
# Jovian Balong rolled: 428
# Elysia Kharim rolled: 797
# Luceth Marithine rolled: 30
# Suija Qualli rolled: 831
# Mozeo Oakden rolled: 321
# Maki Moonfire rolled: 71
# Apple Angelbow rolled: 214
# Deuce Halifax rolled: 851
# Mia Orange rolled: 32
# Rurvyn Reledran rolled: 576
# Sien Clark rolled: 712
# No winner in this simulation.
#
# Simulation 24
# Shiwo Chrysalis rolled: 614
# Hale Draco rolled: 455
# Albatross Balong rolled: 147
# Jovian Balong rolled: 276
# Elysia Kharim rolled: 41
# Luceth Marithine rolled: 932
# Suija Qualli rolled: 637
# Mozeo Oakden rolled: 690
# Maki Moonfire rolled: 855
# Apple Angelbow rolled: 698
# Deuce Halifax rolled: 755
# Mia Orange rolled: 562
# Rurvyn Reledran rolled: 157
# Sien Clark rolled: 966
# No winner in this simulation.
#
# Simulation 25
# Shiwo Chrysalis rolled: 855
# Hale Draco rolled: 6
# Albatross Balong rolled: 721
# Jovian Balong rolled: 844
# Elysia Kharim rolled: 525
# Luceth Marithine rolled: 209
# Suija Qualli rolled: 58
# Mozeo Oakden rolled: 18
# Maki Moonfire rolled: 93
# Apple Angelbow rolled: 802
# Deuce Halifax rolled: 434
# Mia Orange rolled: 204
# Rurvyn Reledran rolled: 460
# Sien Clark rolled: 369
# No winner in this simulation.
#
# Simulation 26
# Shiwo Chrysalis rolled: 854
# Hale Draco rolled: 288
# Albatross Balong rolled: 958
# Jovian Balong rolled: 227
# Elysia Kharim rolled: 93
# Luceth Marithine rolled: 351
# Suija Qualli rolled: 173
# Mozeo Oakden rolled: 721
# Maki Moonfire rolled: 285
# Apple Angelbow rolled: 72
# Deuce Halifax rolled: 756
# Mia Orange rolled: 95
# Rurvyn Reledran rolled: 349
# Sien Clark rolled: 975
# No winner in this simulation.
#
# Simulation 27
# Shiwo Chrysalis rolled: 837
# Hale Draco rolled: 351
# Albatross Balong rolled: 565
# Jovian Balong rolled: 698
# Elysia Kharim rolled: 263
# Luceth Marithine rolled: 302
# Suija Qualli rolled: 678
# Mozeo Oakden rolled: 513
# Maki Moonfire rolled: 639
# Apple Angelbow rolled: 100
# Deuce Halifax rolled: 193
# Mia Orange rolled: 833
# Rurvyn Reledran rolled: 995
# Sien Clark rolled: 707
# No winner in this simulation.
#
# Simulation 28
# Shiwo Chrysalis rolled: 380
# Hale Draco rolled: 53
# Albatross Balong rolled: 871
# Jovian Balong rolled: 402
# Elysia Kharim rolled: 943
# Luceth Marithine rolled: 340
# Suija Qualli rolled: 586
# Mozeo Oakden rolled: 996
# Maki Moonfire rolled: 326
# Apple Angelbow rolled: 685
# Deuce Halifax rolled: 692
# Mia Orange rolled: 498
# Rurvyn Reledran rolled: 947
# Sien Clark rolled: 564
# No winner in this simulation.
#
# Simulation 29
# Shiwo Chrysalis rolled: 856
# Hale Draco rolled: 230
# Albatross Balong rolled: 664
# Jovian Balong rolled: 681
# Elysia Kharim rolled: 100
# Luceth Marithine rolled: 88
# Suija Qualli rolled: 337
# Mozeo Oakden rolled: 15
# Maki Moonfire rolled: 470
# Apple Angelbow rolled: 42
# Deuce Halifax rolled: 963
# Mia Orange rolled: 585
# Rurvyn Reledran rolled: 953
# Sien Clark rolled: 680
# No winner in this simulation.
#
# Simulation 30
# Shiwo Chrysalis rolled: 321
# Hale Draco rolled: 848
# Albatross Balong rolled: 713
# Jovian Balong rolled: 679
# Elysia Kharim rolled: 839
# Luceth Marithine rolled: 874
# Suija Qualli rolled: 38
# Mozeo Oakden rolled: 244
# Maki Moonfire rolled: 385
# Apple Angelbow rolled: 82
# Deuce Halifax rolled: 310
# Mia Orange rolled: 758
# Rurvyn Reledran rolled: 131
# Sien Clark rolled: 993
# No winner in this simulation.
#
# Simulation 31
# Shiwo Chrysalis rolled: 71
# Hale Draco rolled: 414
# Albatross Balong rolled: 310
# Jovian Balong rolled: 559
# Elysia Kharim rolled: 20
# Luceth Marithine rolled: 485
# Suija Qualli rolled: 548
# Mozeo Oakden rolled: 736
# Maki Moonfire rolled: 424
# Apple Angelbow rolled: 960
# Deuce Halifax rolled: 745
# Mia Orange rolled: 906
# Rurvyn Reledran rolled: 229
# Sien Clark rolled: 67
# No winner in this simulation.
#
# Simulation 32
# Shiwo Chrysalis rolled: 814
# Hale Draco rolled: 63
# Albatross Balong rolled: 546
# Jovian Balong rolled: 591
# Elysia Kharim rolled: 534
# Luceth Marithine rolled: 462
# Suija Qualli rolled: 755
# Mozeo Oakden rolled: 419
# Maki Moonfire rolled: 342
# Apple Angelbow rolled: 975
# Deuce Halifax rolled: 966
# Mia Orange rolled: 748
# Rurvyn Reledran rolled: 17
# Sien Clark rolled: 242
# No winner in this simulation.
#
# Simulation 33
# Shiwo Chrysalis rolled: 990
# Hale Draco rolled: 50
# Albatross Balong rolled: 217
# Jovian Balong rolled: 382
# Elysia Kharim rolled: 625
# Luceth Marithine rolled: 928
# Suija Qualli rolled: 504
# Mozeo Oakden rolled: 857
# Maki Moonfire rolled: 444
# Apple Angelbow rolled: 889
# Deuce Halifax rolled: 571
# Mia Orange rolled: 468
# Rurvyn Reledran rolled: 767
# Sien Clark rolled: 55
# No winner in this simulation.
#
# Simulation 34
# Shiwo Chrysalis rolled: 172
# Hale Draco rolled: 124
# Albatross Balong rolled: 404
# Jovian Balong rolled: 367
# Elysia Kharim rolled: 642
# Luceth Marithine rolled: 217
# Suija Qualli rolled: 620
# Mozeo Oakden rolled: 431
# Maki Moonfire rolled: 345
# Apple Angelbow rolled: 697
# Deuce Halifax rolled: 657
# Mia Orange rolled: 733
# Rurvyn Reledran rolled: 895
# Sien Clark rolled: 138
# No winner in this simulation.
#
# Simulation 35
# Shiwo Chrysalis rolled: 705
# Hale Draco rolled: 991
# Albatross Balong rolled: 731
# Jovian Balong rolled: 184
# Elysia Kharim rolled: 338
# Luceth Marithine rolled: 400
# Suija Qualli rolled: 996
# Mozeo Oakden rolled: 560
# Maki Moonfire rolled: 493
# Apple Angelbow rolled: 317
# Deuce Halifax rolled: 756
# Mia Orange rolled: 55
# Rurvyn Reledran rolled: 963
# Sien Clark rolled: 940
# No winner in this simulation.
#
# Simulation 36
# Shiwo Chrysalis rolled: 424
# Hale Draco rolled: 335
# Albatross Balong rolled: 131
# Jovian Balong rolled: 169
# Elysia Kharim rolled: 807
# Luceth Marithine rolled: 113
# Suija Qualli rolled: 328
# Mozeo Oakden rolled: 90
# Maki Moonfire rolled: 692
# Apple Angelbow rolled: 377
# Deuce Halifax rolled: 838
# Mia Orange rolled: 741
# Rurvyn Reledran rolled: 154
# Sien Clark rolled: 248
# No winner in this simulation.
#
# Simulation 37
# Shiwo Chrysalis rolled: 577
# Hale Draco rolled: 42
# Albatross Balong rolled: 39
# Jovian Balong rolled: 13
# Elysia Kharim rolled: 994
# Luceth Marithine rolled: 529
# Suija Qualli rolled: 886
# Mozeo Oakden rolled: 84
# Maki Moonfire rolled: 40
# Apple Angelbow rolled: 669
# Deuce Halifax rolled: 455
# Mia Orange rolled: 306
# Rurvyn Reledran rolled: 174
# Sien Clark rolled: 796
# No winner in this simulation.
#
# Simulation 38
# Shiwo Chrysalis rolled: 65
# Hale Draco rolled: 927
# Albatross Balong rolled: 409
# Jovian Balong rolled: 567
# Elysia Kharim rolled: 344
# Luceth Marithine rolled: 276
# Suija Qualli rolled: 966
# Mozeo Oakden rolled: 969
# Maki Moonfire rolled: 838
# Apple Angelbow rolled: 849
# Deuce Halifax rolled: 233
# Mia Orange rolled: 622
# Rurvyn Reledran rolled: 698
# Sien Clark rolled: 951
# No winner in this simulation.
#
# Simulation 39
# Shiwo Chrysalis rolled: 696
# Hale Draco rolled: 158
# Albatross Balong rolled: 989
# Jovian Balong rolled: 818
# Elysia Kharim rolled: 660
# Rurvyn Reledran rolled: 730
# Sien Clark rolled: 5
# No winner in this simulation.
#
# Simulation 59
# Shiwo Chrysalis rolled: 709
# Hale Draco rolled: 76
# Albatross Balong rolled: 360
# Jovian Balong rolled: 474
# Elysia Kharim rolled: 448
# Luceth Marithine rolled: 316
# Suija Qualli rolled: 66
# Mozeo Oakden rolled: 398
# Maki Moonfire rolled: 789
# Apple Angelbow rolled: 36
# Deuce Halifax rolled: 37
# Mia Orange rolled: 838
# Rurvyn Reledran rolled: 589
# Sien Clark rolled: 842
# No winner in this simulation.
#
# Simulation 60
# Shiwo Chrysalis rolled: 831
# Hale Draco rolled: 975
# Albatross Balong rolled: 167
# Jovian Balong rolled: 404
# Elysia Kharim rolled: 119
# Luceth Marithine rolled: 368
# Suija Qualli rolled: 883
# Mozeo Oakden rolled: 582
# Maki Moonfire rolled: 237
# Apple Angelbow rolled: 179
# Deuce Halifax rolled: 89
# Mia Orange rolled: 172
# Rurvyn Reledran rolled: 528
# Sien Clark rolled: 830
# No winner in this simulation.
#
# Simulation 61
# Shiwo Chrysalis rolled: 316
# Hale Draco rolled: 63
# Albatross Balong rolled: 106
# Jovian Balong rolled: 109
# Elysia Kharim rolled: 292
# Luceth Marithine rolled: 729
# Suija Qualli rolled: 839
# Mozeo Oakden rolled: 139
# Maki Moonfire rolled: 145
# Apple Angelbow rolled: 218
# Deuce Halifax rolled: 318
# Mia Orange rolled: 208
# Rurvyn Reledran rolled: 777
#
# Rurvyn Reledran wins the Dawntrail raffle with the number 777!
# <img src="https://img2.finalfantasyxiv.com/f/fea2829836ffbba374f1820d6431de73_4d9be17b5e1edc617052b4dbf4007875fl0_640x873.jpg?1719456832"/>
# <h2>Winning FC Member Details</h2><table><tr><th>Details</th></tr><tr><td>Race/Clan/Gender</td></tr><tr><td>Viera</td></tr><tr><td>Veena / ♀</td></tr><tr><td>Nameday</td></tr><tr><td>25th Sun of the 5th Astral Moon</td></tr><tr><td>Guardian</td></tr><tr><td>Azeyma, the Warden</td></tr><tr><td>City-state</td></tr><tr><td>Gridania</td></tr><tr><td>Grand Company</td></tr><tr><td>Order of the Twin Adder / Second Serpent Lieutenant</td></tr><tr><td>Free Company</td></tr><tr><td>Nerve</td></tr><tr><td>Attributes</td></tr></table>
# <h2>Simulation Statistics</h2><table><tr><th>Statistic</th><th>Value</th></tr><tr><td>Total Simulations</td><td>61</td></tr><tr><td>Total Winners</td><td>1</td></tr></table>
# <h2>Closest FC Members</h2><table><tr><th>Member</th><th>Rolled Number</th><th>Difference</th></tr><tr><td>Luceth Marithine</td><td>750</td><td>27</td></tr><tr><td>Mia Orange</td><td>833</td><td>56</td></tr><tr><td>Deuce Halifax</td><td>782</td><td>5</td></tr><tr><td>Sien Clark</td><td>718</td><td>59</td></tr><tr><td>Apple Angelbow</td><td>758</td><td>19</td></tr><tr><td>Shiwo Chrysalis</td><td>753</td><td>24</td></tr><tr><td>Mozeo Oakden</td><td>796</td><td>19</td></tr><tr><td>Deuce Halifax</td><td>750</td><td>27</td></tr><tr><td>Albatross Balong</td><td>802</td><td>25</td></tr><tr><td>Luceth Marith